# %%
import COWER
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Data/Example/fixed.csv")
COWER.plot_LCOE_waterfall("FBOW", df1, 11, 5)
df2 = pd.read_csv("Data/Example/floating.csv")
COWER.plot_LCOE_waterfall("FLOW", df2, 11, 5)
